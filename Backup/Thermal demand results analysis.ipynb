# %% [markdown]
# 1. Leemos los datos de los resultados. Ordenamos, agregamos el número de caso y juntamos todo en un solo archivo.

# %%
import pandas as pd
import numpy as np

case1=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 1 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case1=case1.drop([0], axis=0)
case1["case"]= 1

case2=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 2 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case2=case2.drop([0], axis=0)
case2["case"]= 2

case3=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 3 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case3=case3.drop([0], axis=0)
case3["case"]= 3

case4=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 4 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case4=case4.drop([0], axis=0)
case4["case"]= 4

case5=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 5 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case5=case5.drop([0], axis=0)
case5["case"]= 5

case6=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 6 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case6=case6.drop([0], axis=0)
case6["case"]= 6

case7=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 7 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case7=case7.drop([0], axis=0)
case7["case"]= 7


df= pd.concat([case1,case2, case3, case4, case5, case6, case7],axis=0)

df["Date/Time"]= df["Date/Time"].astype('str')

df["Date/Time"]= df["Date/Time"].replace("/","-")


df= df[["Date/Time", "Walls", "Ground Floors" , "Partitions (int)", "Roofs", "External Infiltration", "Total Cooling", "Zone Heating", "Occupancy", "Solar Gains Exterior Windows", "Air Temperature", "Radiant Temperature", "Operative Temperature", "DHW (Electricity)", "Outside Dry-Bulb Temperature","Diffuse Horizontal Solar","Direct Normal Solar", "case"]]

df.to_csv("CleanData/thermal_anual_df.csv", index= False)

# %%
df
# Out:
#                 Date/Time      Walls Ground Floors Partitions (int)  \
# 1      1/01/2002 01:00:00  -0.437293      0.597484         1.685215
# 2      1/01/2002 02:00:00   -0.47839      0.847784         1.638524
# 3      1/01/2002 03:00:00  -0.539379      0.978961         1.394079
# 4      1/01/2002 04:00:00  -0.558632      1.097281         1.215557
# 5      1/01/2002 05:00:00  -0.559379      1.187481          1.05487
# ...                   ...        ...           ...              ...
# 8756  31/12/2002 20:00:00   -0.06908     -1.547715         0.711193
# 8757  31/12/2002 21:00:00  -0.093779     -1.392602          0.76092
# 8758  31/12/2002 22:00:00  -0.139357     -1.228906         0.794144
# 8759  31/12/2002 23:00:00  -0.186026     -1.046471         0.887412
# 8760           31/12/2002  -0.164789     -0.791718         1.233473
#
#           Roofs External Infiltration Total Cooling Zone Heating Occupancy  \
# ...

# %%
radiation=pd.read_csv("DesignBuilder\Casos demanda\Results demand\Radiation anual.csv", encoding= "latin-1", sep=";", skiprows= 1)
radiation=radiation.drop([0], axis=0)
radiation.to_csv("CleanData/radiation.csv", index= False)

# %%
radiation
# Out:
#              Date/Time [1] Site Diffuse Solar Radiation Rate per Area (W/m2)  \
# 1      1/01/2002 01:00                                                  0
# 2      1/01/2002 02:00                                                  0
# 3      1/01/2002 03:00                                                  0
# 4      1/01/2002 04:00                                                  0
# 5      1/01/2002 05:00                                                  0
# ...                ...                                                ...
# 8756  31/12/2002 20:00                                                  0
# 8757  31/12/2002 21:00                                                  0
# 8758  31/12/2002 22:00                                                  0
# 8759  31/12/2002 23:00                                                  0
# 8760   1/01/2003 00:00                                                  0
#
#      [1] Site Direct Solar Radiation Rate per Area (W/m2)
# ...

# %%
case3.columns
# Out:
# Index(['Date/Time', 'Walls', 'Ground Floors', 'Partitions (int)', 'Roofs',
#        'Sensible Cooling', 'Mech Vent + Nat Vent + Infiltration',
#        'External Infiltration', 'External Vent.', 'Total Cooling',
#        'Zone Heating', 'General Lighting', 'Occupancy',
#        'Solar Gains Exterior Windows', 'Zone Sensible Heating',
#        'Zone Sensible Cooling', 'Air Temperature', 'Radiant Temperature',
#        'Operative Temperature', 'Lighting', 'Heating (Gas)',
#        'Cooling (Electricity)', 'DHW (Electricity)',
#        'Outside Dry-Bulb Temperature', 'Unnamed: 24', 'case'],
#       dtype='object')

# %%
pd.options.display.max_columns = None
df
# Out:
#                 Date/Time      Walls Ground Floors Partitions (int)  \
# 1      1/01/2002 01:00:00  -0.437293      0.597484         1.685215
# 2      1/01/2002 02:00:00   -0.47839      0.847784         1.638524
# 3      1/01/2002 03:00:00  -0.539379      0.978961         1.394079
# 4      1/01/2002 04:00:00  -0.558632      1.097281         1.215557
# 5      1/01/2002 05:00:00  -0.559379      1.187481          1.05487
# ...                   ...        ...           ...              ...
# 8756  31/12/2002 20:00:00   -0.06908     -1.547715         0.711193
# 8757  31/12/2002 21:00:00  -0.093779     -1.392602          0.76092
# 8758  31/12/2002 22:00:00  -0.139357     -1.228906         0.794144
# 8759  31/12/2002 23:00:00  -0.186026     -1.046471         0.887412
# 8760           31/12/2002  -0.164789     -0.791718         1.233473
#
#           Roofs External Infiltration Total Cooling Zone Heating Occupancy  \
# ...

# %% [markdown]
# En total se tienen cerca de 26 columnas. Estas tienen datos de la demanda térmica por cerramientos, demanda de calefacción, enfriamiento y otras variables.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61320 entries, 1 to 8760
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date/Time                     61320 non-null  object
#  1   Walls                         61320 non-null  object
#  2   Ground Floors                 61320 non-null  object
#  3   Partitions (int)              61320 non-null  object
#  4   Roofs                         61320 non-null  object
#  5   External Infiltration         61320 non-null  object
#  6   Total Cooling                 43800 non-null  object
#  7   Zone Heating                  61320 non-null  object
#  8   Occupancy                     52560 non-null  object
#  9   Solar Gains Exterior Windows  43800 non-null  object
#  10  Air Temperature               61320 non-null  object
#  11  Radiant Temperature           61320 non-null  object
# ...

# %% [markdown]
# En esta parte se unen todos los casos de estudio, teniendo en cuenta la demanda de diseño para el peor de los casos de cada uno.

# %%
case1_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 1- designdemand.csv", encoding= "latin-1", sep=";")
case1_design["case"]= 1

case2_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 2- designdemand.csv", encoding= "latin-1", sep=";")
case2_design["case"]= 2

case3_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 3- designdemand.csv", encoding= "latin-1", sep=";")
case3_design["case"]= 3

case4_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 4- designdemand.csv", encoding= "latin-1", sep=";")
case4_design["case"]= 4

case5_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 5- designdemand.csv", encoding= "latin-1", sep=";")
case5_design["case"]= 5

case6_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 6- designdemand.csv", encoding= "latin-1", sep=";")
case6_design["case"]= 6

case7_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 7- designdemand.csv", encoding= "latin-1", sep=";")
case7_design["case"]= 7

df_design= pd.concat([case1_design,case2_design, case3_design, case4_design, case5_design, case6_design, case7_design],axis=0)
df_design.to_csv("CleanData/thermal_design_df.csv")

# %%
df_design
# Out:
#            Building     Block   Zone  Comfort Temperature (°C)  \
# Building 1  Block 1    Dorm 9  18.00                      0.46
# Building 1  Block 1   Dorm 10  18.00                      0.41
# Building 1  Block 1   Dorm 11  18.00                      0.41
# Building 1  Block 1   Dorm 12  18.00                      0.41
# Building 1  Block 1   Dorm 13  18.00                      0.41
# ...             ...       ...    ...                       ...
# Building 1  Block 1    Dorm 5  18.00                      1.19
# Building 1  Block 1    Dorm 6  18.00                      1.19
# Building 1  Block 1    Dorm 7  18.00                      1.19
# Building 1  Block 1    Dorm 1  18.00                      1.30
# Building 1  Block 1  Corredor   8.52                      0.00
#
#             Steady-State Heat Loss (kW)  Intermittent Heat Loss (kW)  \
# Building 1                          0.0                         0.57
# ...

# %%
case7_design
# Out:
#   Date/Time    Glazing      Walls Ground Floors      Roofs  \
# 0       NaN         kW         kW            kW         kW
# 1  00:00:00  -0.385848  -2.739521      1.154319  -1.459947
#
#   External Infiltration External Vent. Zone Sensible Heating Air Temperature  \
# 0                    kW             kW                    kW              °C
# 1             -1.498724      -2.750357              8.123114         17.3886
#
#   Radiant Temperature Operative Temperature Outside Dry-Bulb Temperature  \
# 0                  °C                    °C                           °C
# 1            15.78486              16.58673                            0
#
#    Unnamed: 12  case
# 0          NaN     7
# 1          NaN     7
