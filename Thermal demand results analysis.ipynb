# %%
import pandas as pd
import numpy as np

case1=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 1 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case1=case1.drop([0], axis=0)
case1=case1.drop(["Unnamed: 20"], axis=1)
case1["case"]= 1

case2=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 2 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case2=case2.drop([0], axis=0)
case2=case2.drop(["Unnamed: 18"], axis=1)
case2["case"]= 2

case3=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 3 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case3=case3.drop([0], axis=0)
case3=case3.drop(["Unnamed: 20"], axis=1)
case3["case"]= 3

case4=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 4 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case4=case4.drop([0], axis=0)
case4=case4.drop(["Unnamed: 23"], axis=1)
case4["case"]= 4

case5=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 5 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case5=case5.drop([0], axis=0)
case5=case5.drop(["Unnamed: 20"], axis=1)
case5["case"]= 5

case6=pd.read_csv("DesignBuilder\Casos demanda\Results demand\case 6 - thermal demand - hourly.csv", encoding= "latin-1", sep=";")
case6=case6.drop([0], axis=0)
case6=case6.drop(["Unnamed: 23"], axis=1)
case6["case"]= 6

df= pd.concat([case1,case2, case3, case4, case5, case6],axis=0)

df["Date/Time"]= df["Date/Time"].astype('str')

df["Date/Time"]= df["Date/Time"].replace("/","-")

df.to_csv("CleanData/thermal_anual_df.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52560 entries, 1 to 8760
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Date/Time                            52560 non-null  object
#  1   Walls                                52560 non-null  object
#  2   Ground Floors                        52560 non-null  object
#  3   Partitions (int)                     52560 non-null  object
#  4   Roofs                                52560 non-null  object
#  5   Sensible Cooling                     35040 non-null  object
#  6   Mech Vent + Nat Vent + Infiltration  52560 non-null  object
#  7   External Infiltration                52560 non-null  object
#  8   External Vent.                       43800 non-null  object
#  9   Total Cooling                        35040 non-null  object
#  10  Zone Heating                         52560 non-null  object
#  11  General Lighting                     52560 non-null  object
#  12  Occupancy                            52560 non-null  object
#  13  Solar Gains Exterior Windows         35040 non-null  object
#  14  Zone Sensible Heating                52560 non-null  object
#  15  Zone Sensible Cooling                52560 non-null  object
#  16  Air Temperature                      52560 non-null  object
#  17  Radiant Temperature                  52560 non-null  object
#  18  Operative Temperature                52560 non-null  object
#  19  Outside Dry-Bulb Temperature         52560 non-null  object
#  20  case                                 52560 non-null  int64
#  21  Lighting                             26280 non-null  object
#  22  Heating (Gas)                        26280 non-null  object
#  23  Cooling (Electricity)                17520 non-null  object
#  24  DHW (Electricity)                    26280 non-null  object
# dtypes: int64(1), object(24)
# memory usage: 10.4+ MB

# %%
case1_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 1- designdemand.csv", encoding= "latin-1", sep=";")
case1_design["case"]= 1

case2_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 2- designdemand.csv", encoding= "latin-1", sep=";")
case2_design["case"]= 2

case3_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 3- designdemand.csv", encoding= "latin-1", sep=";")
case3_design["case"]= 3

case4_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 4- designdemand.csv", encoding= "latin-1", sep=";")
case4_design["case"]= 4

case5_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 5- designdemand.csv", encoding= "latin-1", sep=";")
case5_design["case"]= 5

case6_design=pd.read_csv("DesignBuilder\Casos demanda\Results design demand\case 6- designdemand.csv", encoding= "latin-1", sep=";")
case6_design["case"]= 6

df_design= pd.concat([case1_design,case2_design, case3_design, case4_design, case5_design, case6_design],axis=0)
df_design.to_csv("CleanData/thermal_design_df.csv")

# %%
case6_design["Design Capacity (kW)"].sum()
# Out:
# 1968.2921999999999

# %%
case6_design
# Out:
#            Building     Block   Zone  Comfort Temperature (°C)  \
# Building 1  Block 1    Dorm 9  18.00                      1.30
# Building 1  Block 1   Dorm 10  18.00                      1.19
# Building 1  Block 1   Dorm 11  18.00                      1.19
# Building 1  Block 1   Dorm 12  18.00                      1.19
# Building 1  Block 1   Dorm 13  18.00                      1.19
# Building 1  Block 1   Dorm 14  18.00                      1.19
# Building 1  Block 1    Dorm 8  18.00                      1.30
# Building 1  Block 1    Dorm 2  18.00                      1.30
# Building 1  Block 1    Dorm 3  18.00                      1.19
# Building 1  Block 1    Dorm 4  18.00                      1.19
# Building 1  Block 1    Dorm 5  18.00                      1.19
# Building 1  Block 1    Dorm 6  18.00                      1.19
# Building 1  Block 1    Dorm 7  18.00                      1.19
# Building 1  Block 1    Dorm 1  18.00                      1.30
# Building 1  Block 1  Corredor   8.52                      0.00
#
#             Steady-State Heat Loss (kW)  Intermittent Heat Loss (kW)  \
# Building 1                          0.0                         1.62
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.62
# Building 1                          0.0                         1.62
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.49
# Building 1                          0.0                         1.62
# Building 1                          0.0                         0.00
#
#             Design Capacity (kW)  Design Capacity (W/m2)  Glazing Gains (kW)  \
# Building 1              150.2974                     0.0              -0.401
# Building 1              136.7707                     0.0              -0.287
# Building 1              136.6650                     0.0              -0.286
# Building 1              136.6641                     0.0              -0.286
# Building 1              136.6650                     0.0              -0.286
# Building 1              136.7708                     0.0              -0.287
# Building 1              150.3131                     0.0              -0.401
# Building 1              150.2974                     0.0              -0.401
# Building 1              136.7707                     0.0              -0.287
# Building 1              136.6650                     0.0              -0.286
# Building 1              136.6641                     0.0              -0.286
# Building 1              136.6650                     0.0              -0.286
# Building 1              136.7708                     0.0              -0.287
# Building 1              150.3131                     0.0              -0.401
# Building 1                0.0000                     0.0               1.649
#
#             Wall Gains (kW)  Floor Gains (kW)  Roof and Ceiling Gains (kW)  \
# Building 1            0.071            -0.825                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.071            -0.825                       -0.044
# Building 1            0.071            -0.825                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.066            -0.826                       -0.044
# Building 1            0.071            -0.825                       -0.044
# Building 1            1.306            -2.620                       -0.083
#
#             Ventilation Gains (kW)  Infiltration Gains (kW)  Unnamed: 14  case
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.099                      NaN          NaN     6
# Building 1                  -0.175                      NaN          NaN     6
